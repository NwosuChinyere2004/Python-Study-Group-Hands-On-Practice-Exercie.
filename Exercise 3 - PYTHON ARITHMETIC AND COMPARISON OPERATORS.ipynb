# %%
basic_salary=180000
bonus=45000
total_salary=basic_salary+bonus
print(total_salary)
total_salary>=220000
# Out:
# 225000
# True

# %% [markdown]
# QUESTION 2

# %%
Python=72
SQL=65
Excel=80
PowerBI=75
Total_score=Python+SQL+Excel+PowerBI
print(Total_score)
# Out:
# 292

# %%
total_score=292
assessment=4
average_score=total_score/assessment
print(average_score)
# Out:
# 73.0

# %%
average_score>=70
# Out:
# True

# %% [markdown]
# QUESTION 3

# %%
initial_stock=250
sold=85
remaining_stock=initial_stock-sold
print(remaining_stock)
remaining_stock<200
# Out:
# 165
# True

# %% [markdown]
# QUESTION 4

# %%
account_balance=520000
withdrawal=150000
remaining_balance=account_balance-withdrawal
print(remaining_balance)
account_balance>=withdrawal
# Out:
# 370000
# True

# %% [markdown]
# BONUS CHALLENGE

# %%
laptop_bag=18500
wireless_mouse=12000
keyboard=24500
USB_Drive=5000
total_purchase=laptop_bag+wireless_mouse+keyboard+USB_Drive
print(total_purchase)
discount_qualify=total_purchase>=50000
print(discount_qualify)
discount_amount=total_purchase*0.10
print(discount_amount)
final_amount=total_purchase-discount_amount
print(final_amount)
# Out:
# 60000
# True
# 6000.0
# 54000.0
