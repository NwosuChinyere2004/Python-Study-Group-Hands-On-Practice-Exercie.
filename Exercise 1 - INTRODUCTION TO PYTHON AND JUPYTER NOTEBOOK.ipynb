# %%
print("Hello World!")
print("My name is Nwosu Chinyere")
print("I am learning Python")
print("programming is exciting!")
# Out:
# Hello World!
# My name is Nwosu Chinyere
# I am learning Python
# programming is exciting!

# %%
print("My favorite food is Okro soup and fufu")
print("My favorite movie is Monica")
print("My favorite sport is Table Tennis")
print("My favorite colour is Brown")
# Out:
# My favorite food is Okro soup and fufu
# My favorite movie is Monica
# My favorite sport is Table Tennis
# My favorite colour is Brown

# %%
print(15+5)
# Out:
# 20

# %%
print(30-12)
# Out:
# 18

# %%
print(9*8)
# Out:
# 72

# %%
print(72/9)
# Out:
# 8.0

# %%
print(18%5)
# Out:
# 3

# %%
print(10//3)
# Out:
# 3

# %%
print(5**2)
# Out:
# 25

# %%
# Display programing language 
print("Welcome to Python")

# what are you learning
print("I am learning programming")

# what lesson are you learning today
print("Lesson one")
# Out:
# Welcome to Python
# I am learning programming
# Lesson one

# %%
print("My name is Nwosu Chinyere")
print("My dream career is to become a Data Analytics")
print("I am from Nigeria")
# Out:
# My name is Nwosu Chinyere
# My dream career is to become a Data Analytics
# I am from Nigeria

# %%
print(25+75)
# Out:
# 100

# %%
print(40//6)
# Out:
# 6

# %%
print(8**2)
# Out:
# 64

# %%
# show the year we are in
print("July")

# the subject you enjoy most
print("Mathematics")

# execute python code
print("Python is awesome!")
# Out:
# July
# Mathematics
# Python is awesome!
