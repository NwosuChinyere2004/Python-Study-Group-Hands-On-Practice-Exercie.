# %% [markdown]
# EXERCISE 1

# %%
print("name:","Chinyere Nwosu")
print("Age:","32")
print("Country:","Nigeria")
# Out:
# name: Chinyere Nwosu
# Age: 32
# Country: Nigeria

# %% [markdown]
# EXERCISE 2

# %%
Name=input("Enter your name: ")
print("Hello","Chinyere")
programming_language=input("Enter your programming_language: ")
print("My favourite programming_language is",programming_language)
# Out:
# Enter your name:  Chinyere
# Hello Chinyere
# Enter your programming_language:  Python
# My favourite programming_language is Python

# %% [markdown]
# EXERCISE 3

# %%
Salary=180000
Bonus=35000
Total=Salary+Bonus
print(Total)
# Out:
# 215000

# %% [markdown]
# EXERCISE 4

# %%
Age=70
Scale=8.4
State="Imo"
Monthly_income=True
print(type(Age))
print(type(Scale))
print(type(State))
print(type(Monthly_income))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>

# %% [markdown]
# EXERCISE 5

# %%
Age=50
print(type(Age))
Name="Chinyere"
print(type(Name))
# Out:
# <class 'int'>
# <class 'str'>

# %% [markdown]
# MINI PROJECT

# %% [markdown]
# STUDENT INFORMATION CARD

# %%
print("Name:","Chinyere Nwosu")
print("Age:","32")
print("Course:","python programming_language")
print("Country:","Nigeria")
name="Chinyere Nwosu"
Age="32"
Course="python programming_language"
Country="Nigeria"
print(type(name))
print(type(Age))
print(type(Course))
print(type(Country))
Age=25
print(type(Age))
# Out:
# Name: Chinyere Nwosu
# Age: 32
# Course: python programming_language
# Country: Nigeria
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
