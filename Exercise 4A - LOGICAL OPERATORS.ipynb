# %%
username_correct=True
password_correct=True
account_locked=False

if username_correct and password_correct and not account_locked:
    print("Access Granted")
else:
    print("Access Denied")
# Out:
# Access Granted

# %%
password_wrong=False
account_locked=False
username_incorrect=False

if password_wrong and account_locked and not username_wrong:
    print("Access Granted")
else:
    print("Access Denied")
# Out:
# Access Denied

# %% [markdown]
# Hands-on 2

# %%
score=85
participated=True
low_income=False

if score>=80 and (participated or low_income):
    print("Congratulation!")
    print("Scholarship Approved.")
else:
    print("Scholarship Not Approved.")
# Out:
# Congratulation!
# Scholarship Approved.

# %% [markdown]
# CHALLENGE MYSELF

# %%
Score=85
participated=False
low_income=False

if score>=80 and (participated or low_income):
    print("Congratulations!")
    print("Scholarship Approved.")
else:
    print("Scholarship Not Approved.")
# Out:
# Scholarship Not Approved.

# %%
score=75
participated=True
low_income=False

if score>=80 and (participation or low_income):
    print("Congratulation!")
    print("Scholarship Approved.")
else:
    print("Scholarship Not Approved.")
# Out:
# Scholarship Not Approved.

# %%
score=90
participated=False
low_income=True

if score>=80 and (participated or low_income):
    print("Congratulation!")
    print("Scholarship Approved.")
else:
    print("Scholarship Not Approved.")
# Out:
# Congratulation!
# Scholarship Approved.

# %%
score=95
participated=True
low_income=True

if score>=80 and (participated or low_income):
    print("Congratulation!")
    print("Scholarship Approved.")
else:
    print("Scholarship Not Approved.")
# Out:
# Congratulation!
# Scholarship Approved.

# %% [markdown]
# HANDS-ON 3

# %%
cpu_usage=75
memory_usage=92
disk_usage=60

if cpu_usage>90 or memory_usage>90 or disk_usage>95:
    print("Critical Alert!")
else:
    print("System Healthy")
# Out:
# Critical Alert!

# %% [markdown]
# CHALLENGE MYSELF

# %%
cpu_usage=70
memory_usage=80
disk_usage=60

if cpu_usage>90 or memory_usage>90 or disk_usage>95:
    print("Critical Alert!")
else:
    print("System Healthy")
# Out:
# System Healthy

# %%
cpu_usage=95
memory_usage=80
disk_usage=60

if cpu_usage>90 or memory_usage>90 or disk_usage>95:
    print("Critical Alert!")
else:
    print("System Healthy")
# Out:
# Critical Alert!

# %%
cpu_usage=75
memory_usage=95
disk_usage=60

if cpu_usage>90 or memory_usage>90 or disk_usage>95:
    print("Critical Alert!")
else:
    print("System Healthy")
# Out:
# Critical Alert!

# %%
cpu_usage=75
memory_usage=80
disk_usage=96

if cpu_usage>90 or memory_usage>90 or disk_usage>95:
    print("Critical Alert!")
else:
    print("System Healthy")
# Out:
# Critical Alert!

# %%
cpu_usage=95
memory_usage=96
disk_usage=98

if cpu_usage>90 or memory_usage>90 or disk_usage>95:
    print("Critical Alert!")
else:
    print("System Healthy")
# Out:
# Critical Alert!

# %% [markdown]
# Any of the conditions causes the alert to trigger
