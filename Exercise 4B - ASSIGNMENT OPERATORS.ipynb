# %%
score=60
score+=15
score-=5
score*=2
print(score)
# Out:
# 140

# %% [markdown]
# BONUS CHALLENGE

# %%
score=int(input("Enter the initial score:"))
          
score+=15
score-=5
score*=2
# Out:
# Enter the initial score: 60

# %% [markdown]
# HANDS-ON 2

# %%
balance=25000

balance+=8500
balance-=4200
balance/=3

print("final balance",balance)
print(type(balance))
# Out:
# final balance 9766.666666666666
# <class 'float'>

# %% [markdown]
# BONUS CHALLENGE

# %%
balance=25000

deposit=input("Enter deposit amount!")
withdrawal=input("Enter withdrawal amount:")
# Out:
# Enter deposit amount! 8500
# Enter withdrawal amount: 4200

# %% [markdown]
# HANDS-ON 3

# %%
stock=150
stock-=28
stock+=75
stock//=12

print(" number of full cartons:",stock)
# Out:
#  number of full cartons: 16

# %% [markdown]
# BONUS CHALLENGE

# %%
initial_stock=input("Enter the initial_stock:")
print("items sold:",stock)
print("new items arrive",stock)
print("how many items fit into one carton",stock)
print((
# Out:
# Enter the initial_stock: 150
# items sold: 16
# new items arrive 16
# how many items fit into one carton 16
