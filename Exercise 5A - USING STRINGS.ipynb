# %%
# Customer Registration System

customer_name="John Doe"
email="johndoe@gmail.com"
phone="08045879211"
country="Nigeria"
occupation="Teacher"

print("Customer Registration")
print()
print("Name:",customer_name)
print("Email:",email)
print("phone:",phone)
print("Country:",country)
print("Occupation:",occupation)
# Out:
# Customer Registration
#
# Name: John Doe
# Email: johndoe@gmail.com
# phone: 08045879211
# Country: Nigeria
# Occupation: Teacher

# %%
# Hospital Patient Record

patient_name="Mary Johnson"
doctor="Dr.Okeke"
diagnosis="Malaria"
blood_group="O+"
hospital="Imo State Specialist Hospital"


record=f"""
PATIENT RECORD

Patient:{patient_name}
Doctor:{doctor}
Diagnosis:{diagnosis}
Blood Group:{blood_group}
Hospital:{hospital}
"""

print(record)
# Out:
# PATIENT RECORD
#
# Patient:Mary Johnson
# Doctor:Dr.Okeke
# Diagnosis:Malaria
# Blood Group:O+
# Hospital:Imo State Specialist Hospital

# %%
# AI Prompt Builder

prompt="""
You are an AI Assistant.

Analyse customer feedback.
Identify common complaints.
Provide recommendations.
Generate a summary report.
Always give a clear and professional answers.
"""

print(prompt)
# Out:
# You are an AI Assistant.
#
# Analyse customer feedback.
# Identify common complaints.
# Provide recommendations.
# Generate a summary report.
# Always give a clear and professional answers.

# %%
# Customer Feedback Management System
customer_name="Chinyere Nwosu"
product_name="HP Laptop"
product_category="Electronics"
customer_rating="5 Stars"
customer_review="The Laptop is fast, reliable, and easy to use."

report=f"""
=============================
   CUSTOMER FEEDBACK REPORT
=============================

Customer Name:{customer_name}
Product Name:{product_name}
Product Category:{product_category}
Customer Rating:{customer_rating}

Customer Review:
{customer_review}

======================================
Thank you for your valuable feedback!
======================================
"""
print(report)
# Out:
# ...
#    CUSTOMER FEEDBACK REPORT
# ...
#
# Customer Name:Chinyere Nwosu
# Product Name:HP Laptop
# Product Category:Electronics
# Customer Rating:5 Stars
#
# Customer Review:
# The Laptop is fast, reliable, and easy to use.
#
# ...
# Thank you for your valuable feedback!
# ...
